# %%
#  Gerekli kütüphaneler
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
import os



# Google Drive'da model dosyalarının kaydedileceği klasör
model_dir = '/content/drive/MyDrive/AlzheimerModels'
os.makedirs(model_dir, exist_ok=True)

# Dataset klasörleri (hazır bölünmüş)
train_dir = '/content/drive/MyDrive/Alzheimer_dataset/Splitted_OriginalDataset/train'
val_dir = '/content/drive/MyDrive/Alzheimer_dataset/Splitted_OriginalDataset/val'
test_dir = '/content/drive/MyDrive/Alzheimer_dataset/Splitted_OriginalDataset/test'

#  Data augmentation ve preprocessing
batch_size = 128
img_size = (176, 208)

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    zoom_range=0.2,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='sparse',
    shuffle=True
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='sparse',
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='sparse',
    shuffle=False
)

from tensorflow.keras import backend as K
K.clear_session()

# DenseNet121 tabanlı model
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(176, 208, 3))
base_model.trainable = True
for layer in base_model.layers[:20]:
    layer.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(4, activation='softmax')
])

model.compile(
    optimizer=AdamW(learning_rate=1e-4, weight_decay=1e-5),
    loss=SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# Callbacks
tensorboard_cb = TensorBoard(log_dir='/content/logs_densenet121')
early_stopping_cb = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

best_model_path = os.path.join(model_dir, 'best_model_densenet.keras')

checkpoint_cb = ModelCheckpoint(
    filepath=best_model_path,
    save_best_only=True,
    monitor='val_loss',
    verbose=1
)

#  Class weights (dengesiz sınıf için)
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))

#  Modeli eğit
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[tensorboard_cb, early_stopping_cb, reduce_lr_cb, checkpoint_cb]
)

#  En iyi model yüklenip final olarak kaydedilir
final_model_path = os.path.join(model_dir, 'final_model_densenet.keras')
best_model = load_model(best_model_path)
best_model.save(final_model_path)

print(f"\n Eğitim tamamlandı ve model Google Drive'a kaydedildi: {final_model_path}")
# Out:
# Found 4479 images belonging to 4 classes.
# Found 960 images belonging to 4 classes.
# Found 961 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 38s/step - accuracy: 0.3130 - loss: 1.6591
# Epoch 1: val_loss improved from inf to 1.19726, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1957s 51s/step - accuracy: 0.3140 - loss: 1.6567 - val_accuracy: 0.4208 - val_loss: 1.1973 - learning_rate: 1.0000e-04
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4168 - loss: 1.1635
# Epoch 2: val_loss improved from 1.19726 to 1.16594, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.4177 - loss: 1.1613 - val_accuracy: 0.5354 - val_loss: 1.1659 - learning_rate: 1.0000e-04
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4915 - loss: 0.9647
# Epoch 3: val_loss improved from 1.16594 to 1.05633, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.4918 - loss: 0.9627 - val_accuracy: 0.5521 - val_loss: 1.0563 - learning_rate: 1.0000e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5299 - loss: 0.9442
# Epoch 4: val_loss improved from 1.05633 to 1.03659, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5302 - loss: 0.9407 - val_accuracy: 0.5458 - val_loss: 1.0366 - learning_rate: 1.0000e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5626 - loss: 0.7103
# Epoch 5: val_loss improved from 1.03659 to 0.99919, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5627 - loss: 0.7103 - val_accuracy: 0.5521 - val_loss: 0.9992 - learning_rate: 1.0000e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6039 - loss: 0.6318
# Epoch 6: val_loss did not improve from 0.99919
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.6041 - loss: 0.6317 - val_accuracy: 0.5448 - val_loss: 1.0199 - learning_rate: 1.0000e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6315 - loss: 0.6067
# Epoch 7: val_loss did not improve from 0.99919
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.6313 - loss: 0.6073 - val_accuracy: 0.5531 - val_loss: 1.1010 - learning_rate: 1.0000e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6358 - loss: 0.6101
# Epoch 8: val_loss improved from 0.99919 to 0.97772, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.6356 - loss: 0.6105 - val_accuracy: 0.5938 - val_loss: 0.9777 - learning_rate: 1.0000e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6895 - loss: 0.5240
# Epoch 9: val_loss improved from 0.97772 to 0.66107, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.6891 - loss: 0.5244 - val_accuracy: 0.7104 - val_loss: 0.6611 - learning_rate: 1.0000e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6753 - loss: 0.5271
# Epoch 10: val_loss did not improve from 0.66107
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.6755 - loss: 0.5268 - val_accuracy: 0.6448 - val_loss: 0.7843 - learning_rate: 1.0000e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6965 - loss: 0.4919
# Epoch 11: val_loss improved from 0.66107 to 0.63715, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.6967 - loss: 0.4924 - val_accuracy: 0.7385 - val_loss: 0.6372 - learning_rate: 1.0000e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6896 - loss: 0.5304
# Epoch 12: val_loss did not improve from 0.63715
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.6902 - loss: 0.5294 - val_accuracy: 0.7271 - val_loss: 0.6594 - learning_rate: 1.0000e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7509 - loss: 0.4114
# Epoch 13: val_loss did not improve from 0.63715
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7511 - loss: 0.4113 - val_accuracy: 0.7250 - val_loss: 0.6565 - learning_rate: 1.0000e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7650 - loss: 0.3642
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 14: val_loss did not improve from 0.63715
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7651 - loss: 0.3643 - val_accuracy: 0.7240 - val_loss: 0.6825 - learning_rate: 1.0000e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7923 - loss: 0.3376
# Epoch 15: val_loss improved from 0.63715 to 0.57510, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.7923 - loss: 0.3374 - val_accuracy: 0.7573 - val_loss: 0.5751 - learning_rate: 5.0000e-05
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8111 - loss: 0.3038
# Epoch 16: val_loss improved from 0.57510 to 0.52664, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.8110 - loss: 0.3038 - val_accuracy: 0.7812 - val_loss: 0.5266 - learning_rate: 5.0000e-05
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8230 - loss: 0.2972
# Epoch 17: val_loss did not improve from 0.52664
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8229 - loss: 0.2973 - val_accuracy: 0.7552 - val_loss: 0.6104 - learning_rate: 5.0000e-05
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8352 - loss: 0.2645
# Epoch 18: val_loss improved from 0.52664 to 0.48112, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.8351 - loss: 0.2647 - val_accuracy: 0.8083 - val_loss: 0.4811 - learning_rate: 5.0000e-05
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8488 - loss: 0.2512
# Epoch 19: val_loss improved from 0.48112 to 0.45248, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.8488 - loss: 0.2512 - val_accuracy: 0.8104 - val_loss: 0.4525 - learning_rate: 5.0000e-05
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8448 - loss: 0.2361
# Epoch 20: val_loss did not improve from 0.45248
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8450 - loss: 0.2361 - val_accuracy: 0.7948 - val_loss: 0.5070 - learning_rate: 5.0000e-05
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8572 - loss: 0.2208
# Epoch 21: val_loss did not improve from 0.45248
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.8576 - loss: 0.2205 - val_accuracy: 0.7781 - val_loss: 0.5566 - learning_rate: 5.0000e-05
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8664 - loss: 0.2169
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 22: val_loss did not improve from 0.45248
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.8665 - loss: 0.2168 - val_accuracy: 0.7906 - val_loss: 0.5478 - learning_rate: 5.0000e-05
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8645 - loss: 0.2374
# Epoch 23: val_loss did not improve from 0.45248
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.8648 - loss: 0.2367 - val_accuracy: 0.8104 - val_loss: 0.5148 - learning_rate: 2.5000e-05
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8872 - loss: 0.1819
# Epoch 24: val_loss improved from 0.45248 to 0.39322, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.8872 - loss: 0.1819 - val_accuracy: 0.8500 - val_loss: 0.3932 - learning_rate: 2.5000e-05
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8882 - loss: 0.1803
# Epoch 25: val_loss did not improve from 0.39322
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.8882 - loss: 0.1802 - val_accuracy: 0.8333 - val_loss: 0.4245 - learning_rate: 2.5000e-05
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9033 - loss: 0.1605
# Epoch 26: val_loss did not improve from 0.39322
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9034 - loss: 0.1603 - val_accuracy: 0.8521 - val_loss: 0.3962 - learning_rate: 2.5000e-05
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9029 - loss: 0.1625
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 27: val_loss did not improve from 0.39322
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9029 - loss: 0.1624 - val_accuracy: 0.8500 - val_loss: 0.4083 - learning_rate: 2.5000e-05
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9132 - loss: 0.1475
# Epoch 28: val_loss did not improve from 0.39322
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9132 - loss: 0.1476 - val_accuracy: 0.8427 - val_loss: 0.4033 - learning_rate: 1.2500e-05
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9111 - loss: 0.1468
# Epoch 29: val_loss improved from 0.39322 to 0.37667, saving model to /content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9111 - loss: 0.1468 - val_accuracy: 0.8646 - val_loss: 0.3767 - learning_rate: 1.2500e-05
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9124 - loss: 0.1457
# Epoch 30: val_loss did not improve from 0.37667
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9125 - loss: 0.1456 - val_accuracy: 0.8604 - val_loss: 0.3834 - learning_rate: 1.2500e-05
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9204 - loss: 0.1271
# Epoch 31: val_loss did not improve from 0.37667
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9204 - loss: 0.1273 - val_accuracy: 0.8333 - val_loss: 0.4517 - learning_rate: 1.2500e-05
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9239 - loss: 0.1293
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 32: val_loss did not improve from 0.37667
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9238 - loss: 0.1294 - val_accuracy: 0.8323 - val_loss: 0.4548 - learning_rate: 1.2500e-05
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9213 - loss: 0.1336
# Epoch 33: val_loss did not improve from 0.37667
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9213 - loss: 0.1335 - val_accuracy: 0.8500 - val_loss: 0.4106 - learning_rate: 6.2500e-06
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9143 - loss: 0.1378
# Epoch 34: val_loss did not improve from 0.37667
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9146 - loss: 0.1376 - val_accuracy: 0.8500 - val_loss: 0.3949 - learning_rate: 6.2500e-06
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9294 - loss: 0.1231
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 35: val_loss did not improve from 0.37667
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9295 - loss: 0.1232 - val_accuracy: 0.8510 - val_loss: 0.4025 - learning_rate: 6.2500e-06
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9217 - loss: 0.1221
# Epoch 36: val_loss did not improve from 0.37667
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9218 - loss: 0.1221 - val_accuracy: 0.8469 - val_loss: 0.4152 - learning_rate: 3.1250e-06
#
# ✅ Eğitim tamamlandı ve model Google Drive'a kaydedildi: /content/drive/MyDrive/AlzheimerModels/final_model_densenet.keras

# %%
import gradio as gr
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

#  Sınıf isimleri
class_names = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']



model = load_model("/content/drive/MyDrive/AlzheimerModels/best_model_densenet.keras")

# Tahmin fonksiyonu
def predict(img):
    img = img.resize((208, 176))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    preds = model.predict(img_array)[0]
    predicted_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    return f"{predicted_class} ({confidence:.2%})"

#  Gradio arayüzü
interface = gr.Interface(
    fn=predict,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="🧠 Alzheimer MRI Tahmin Arayüzü (DenseNet121)",
    description="Bir MRI görüntüsü yükleyin ve modelin tahminini görün."
)

#  Arayüzü başlat
interface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b277197776eee35f71.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b277197776eee35f71.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
